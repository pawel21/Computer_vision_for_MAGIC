# %%
import h5py
import numpy as np
from PIL import Image
import cv2

# %% [markdown]
# # Normalizacja
#
# ## Normalizacja fotometryczna
#
# - konwersja do grayscale
# - normalizacja: img = (img - np.mean(img)) / np.std(img)
